// %%
Protected - klasy potomne mają dostęp

// %%
hashset - zbiór{}
* unikalne wartości
* brak kolejności
HashSet<string> uzytkownicy = new();
var uzytkownicy = new HashSet<string>();
uzytkownicy.Add("Marek");

// %%
dictionary
* unikalność kluczy 
* wartości mogą się powtarzać
Dictionary<string, List<string>> slownik = new();
var slownik = new Dictionary<string, List<string>>();
slownik.add("key1", new());
slownik["key1"].add("test");

// %% [markdown]
// strzałka przerywana - używa: wskazuje na to co potrzebuje
// strzałka ciągła - dziedziczy: wskazuje na rodzica
