// %%
#include <stdio.h>
#include <stdlib.h>
int main() {
int i, sum, numbers[5];
for(i=0; i<5; i++){
numbers[i] = i+1;
printf("%3d", numbers[i]);
}
for(i=0, sum=0; i<5; i++){
sum += numbers[i];
}
printf("\nSum of elements: %d", sum);
return 0;
}
// Out:
//   1  2  3  4  5
// Sum of elements: 15

// %%
#include <stdio.h>
#include <stdlib.h>
int main() {
int numbers[5];
numbers[1] = 1;
printf("%d",numbers[1]);
numbers[1] = 2;
printf("%d",numbers[1]);


}
// Out:
// 12

// %%
#include <stdio.h>
int a = 123;
int b = 3;
int main() {
    printf("%d\n",a);
    printf("%3d\n",b);
}
// Out:
// 123
//   3

// %%
int src[] = {1, 2, 3, 4, 5};
int dest[5];
int main() {
for (int i = 0; i < 5; i++)
    dest[i] = src[i];
    }

// %%
#include <string.h>

int src[] = {1, 2, 3, 4, 5};
int dest[5];
int main() {
memcpy(dest, src, sizeof(src));
}

// %%
#include <stdio.h>
int main(){
    char msg[] = "test";
    printf("%s\n", msg);
    puts(msg);


}
// Out:
// test
// test

// %%
scanf("%19[^\n]s", name);
gets(name); // Moze nadpisac bufor
fgets(name, 20, stdin);

// %%
#include <ctype.h>
int c = "1";
int isalpha(c); // false
int isdigit(c); // true
