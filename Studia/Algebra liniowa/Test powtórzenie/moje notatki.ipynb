# %%
A.echelon_form() # postac shhodkowa
A.rank() # moc 
A.inverse()
A.rref() # postac bazowa 
A.transpose()
I=identity_matrix(3) # jednostkowa macie 
A.solve_right()
A.solve_right()

# %%
A = matrix([[0,6,3],[-1,-2,1]])
B = matrix([[6,0],[1,-2]])
X = A.solve_right(B)

print(A)
print()
print(B)
print()
print(X)
# Out:
# [ 0  6  3]
# [-1 -2  1]
#
# [ 6  0]
# [ 1 -2]
#
# [-3  2]
# [ 1  0]
# [ 0  0]

# %%
a,b,c,d = var('a,b,c,d')
X = matrix(2,2,[a,b,c,d])
A = matrix([[1,0],[1,1]])
B = matrix([[1,0],[2,1]])
C = X*A - B*X
solution = solve(C.list(), a,b,c,d)
solution
# Out:
# [[a == 1/2*r3, b == 0, c == r4, d == r3]]

# %%
a = matrix([[1, 2], [3, 4]])
b = matrix([[5], [6]])
show("Solving the equation: A*x = b")
show("A =", a)
show("b =", b)
x=a.solve_right(b)
print(x)
# Out:
# [ -4]
# [9/2]

# %%
# X*A - B*X
from math import log, log2
from sre_constants import LITERAL_LOC_IGNORE


a,b,c,d = var('a b c d')
X = Matrix([[a, b], [c, d]])
A = Matrix([[1, 0], [1, 1]])
B = Matrix([[1, 0], [2, 1]])
rozw = solve([c == 0 for c in (X*A - B*X).list()])

#roz=solve([c==0 for c in(A*X-I).list()],[p,q,r,s,t,w,u,x,z])

#solve
# [c == 0 for c in (X*A - B*X)] --> liste
rozw

rozw = solve([c == 0 for c in (X*A - B*X).list()])
# Out:
# [[a == 1/2*r2, b == 0, d == r2]]

# %% [markdown]
# Permutacje

# %%
s = PermutationGroupElement([2,3,1,5,4,8,10,9,7,6])

lcm([c.order() for c in s.cycles()])

s.order()  # Oblicza rząd (liczbę elementów) permutacji s, czyli najmniejszą liczbę, po której permutacja zastosowana wielokrotnie daje permutację identyczną
# Out:
# 30

# %%
#parzystosc permutacji
a = PermutationGroupElement([2,3,1,5,4,8,10,9,7,6])
print(a)
print(a.sign())
# Out:
# (1,2,3)(4,5)(6,8,9,7,10)
# -1
