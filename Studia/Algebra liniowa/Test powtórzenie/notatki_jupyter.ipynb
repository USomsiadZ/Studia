# %% [markdown]
# #RÓWNANIA Z NIEWIADOMĄ X:
#
# #a)

# %%
a=matrix([[0,6,3],[-1,-2,1]])

b=matrix([[6,0],[1,-2]])

x=a.solve_right(b)

print(x)

# %%
a,b,c,d = var('a b c d')

X = Matrix([[a, b], [c, d]])

A = Matrix([[1, 0], [1, 1]])

B = Matrix([[1, 0], [2, 1]])

rozw = solve([c == 0 for c in (X*A - B*X).list()])
# Out:
#   Cell In[55], line 12
#     roz2 solve([[a == Integer(1)/Integer(2)*r191, b == Integer(0), d == r191]],[a,b,c,d])
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #POSTAĆ SCHODKOWA I RZĄD MACIERZY:
#
# #a

# %%
A=matrix([[2,-1,1,-1],[1,1,1,1],[2,0,2,2]])

wyn=A.echelon_form()

b=A.rank()

print(b)

wyn

# %% [markdown]
# DEFINICJA I OPERACJE ELEMENTARNE
#
# #c

# %%
p,q,r,s,t,w,u,x,z=var('p,q,r,s,t,w,u,x,z')

A=matrix([[1,0,2],[2,1,1],[2,1,0]])

X=matrix([[p,q,r],[s,t,w],[u,x,z]])

# z definicji

I=identity_matrix(3) # jednostkowa macie 

roz=solve([c==0 for c in(A*X-I).list()],[p,q,r,s,t,w,u,x,z])

roz2=X.subs(roz)

roz2
roz
# Out:
# [[p == 1, q == -2, r == 2, s == -2, t == 4, w == -3, u == 0, x == 1, z == -1]]

# %% [markdown]
# #operacje elementarne

# %%
A=matrix([[1,0,2],[2,1,1],[2,1,0]])

u=A.augment(I).echelon_form()

X=A.solve_right(I)

X
# Out:
# [ 1 -2  2]
# [-2  4 -3]
# [ 0  1 -1]

# %% [markdown]
# POSTAĆ BAZOWA:
#
# #a

# %%
A=matrix([[1,-1,2],[-2,3,1],[5,-7,-4]])

roz=A.rref()

rzad=roz.rank()

print(rzad)

roz

# %% [markdown]
# #ROZWIĄZYWANIE METODY KOLUMN JEDNOSTRKOWYCH:

# %%
A=matrix([[2,-1,1],[-4,-12,1],[3,3,1]])

B=vector([1,2,3])

x,y,z,t=var('x,y,z,t')

X=vector([x,y,z,t])

U=A.augment(B,subdivide=True).rref()

solve([c==0 for c in(A*X-B).list()],[x,y,z,t])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 11
#       7 X=vector([x,y,z,t])
#       9 U=A.augment(B,subdivide=True).rref()
# ---> 11 solve([c==Integer(0) for c in(A*X-B).list()],[x,y,z,t])
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/element.pyx:4121, in sage.structure.element.Matrix.__mul__ (build/cythonized/sage/structure/element.c:37057)()
#    4119
#    4120         if BOTH_ARE_ELEMENT(cl):
# -> 4121             return coercion_model.bin_op(left, right, mul)
#    4122
#    4123         cdef long value
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/coerce.pyx:1288, in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:17545)()
#    1286     # We should really include the underlying error.
#    1287     # This causes so much headache.
# -> 1288     raise bin_op_exception(op, x, y)
#    1289
#    1290 cpdef canonical_coercion(self, x, y):
#
# TypeError: unsupported operand parent(s) for *: 'Full MatrixSpace of 3 by 3 dense matrices over Integer Ring' and 'Vector space of dimension 4 over Symbolic Ring'

# %% [markdown]
# SZUKANIE ELEMENTU e W PERMUTACJACH:

# %%
s = PermutationGroupElement([2,3,1,5,4,8,10,9,7,6])

lcm([c.order() for c in s.cycles()])

s.order()
# Out:
# 30

# %% [markdown]
# PERMUTACJE:

# %%
s=PermutationGroupElement([2,5,3,1,4])

t=PermutationGroupElement([4,5,2,1,3])

print(Permutation(t*s))

print(Permutation(s*t))

print(Permutation(s^4))

print(Permutation(t^(-1)))

print(Permutation(t^2021))

# %% [markdown]
# PERMUTACJA TA CO BYŁA U RAJMUNDA:

# %%
a=PermutationGroupElement([9,1,4,2,6,5,3,8,7])

s=PermutationGroupElement([4,7,6,5,1,9,2,3,8])

t=Permutation((s^(-1))*a*(s^(26)))

t

# %% [markdown]
# CIAŁA:

# %%
cialo=GF(29)

print(cialo(27*5-19))

print(cialo(12^(-1)))

print(cialo(4*21^(-3)+3^4*5-2^(-6)))
