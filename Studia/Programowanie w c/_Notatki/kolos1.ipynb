// %% [markdown]
// # Include
// ```c
// #include <stdlib.h> //Srand i rand
// #include <ctype.h>    //isalpha, tolower
// ```

// %% [markdown]
// # Czyszczenie bufora
// ```c
// while (getchar() != '\n'); // czyszczenie bufora wejściowego
// ```

// %% [markdown]
// # String
// ```c
// strlen(a); // wypisuje długość napisu
// strcpy(a,b); // zapisuje a <- b
// strcat(a,b); // dopisuje a <- b
// ```

// %% [markdown]
// # Tablice
// ```c
// char a[6] = "jakis";
// int b[2][2] = {{1,2},{1,2}}
// ```

// %% [markdown]
// # Random
// ```c
// srand(time(NULL));
// rand() % 5;
//
// ```

// %% [markdown]
// # Wskaźniki
// ```c
// void dodawacz(int *a){
//     *a += 10;
// }
// int main(){
//     int a = 10;
//     dodawacz(&a);
// }
// ```

// %% [markdown]
// # ifndef
// ```c
// #ifndef KOSZT
// #define KOSZT 6
// #endif
// ```
