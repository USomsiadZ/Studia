# %% [markdown]
# -it to dwa przełączniki naraz:
#
# -i – trzyma STDIN otwarte, żebyś mógł wpisywać komendy.
#
# -t – tworzy pseudo-terminal (TTY), czyli daje normalny „interaktywny” terminal

# %%
docker start ubuntu_kontener

docker exec -it ubuntu_kontener bash
