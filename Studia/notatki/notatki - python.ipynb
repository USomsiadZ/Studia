# %%
a = "ala"
a.split('l')
# Out:
# ['a', 'a']

# %%
x = 2.3333333333
round(x, 2)

# %%
print(f'Wartość zmiennej x to {x}!')

# %%
#x[start_index : end_index : step]
x = [3, -2, 7, 0, 4]
print(x[0::2])
sorted(x)
# Out:
# [3, 7, 4]
# [-2, 0, 3, 4, 7]

# %%
print([3*x for x in range(7)])
[3*x for x in range(7) if x % 2 == 1]  # wypisuje 3x tylko dla liczb nieparzystych: 1, 3, 5

# %%
# Out:
#   Cell In[1], line 1
#     [i for i in [1..5]]
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
