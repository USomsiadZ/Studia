// %%
using System;
using System.IO;

string[] tab = {"a","b"};
string.Join(" ", tab);// a b 

//if A != null => x = A else x = b
int? A = null;
int B = 5;
int x = A ?? B;

string katalog = "/";
Path.Combine(katalog, "klucz.txt");

using System.Collections.Generic;
List<string> liniaOdpowiedzi = [];

liczby = null; // garbage colector usunie tablice
// Out:
// <div class="dni-plaintext"><pre>6</pre></div><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
