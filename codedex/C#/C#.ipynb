# %%
// Array
using System.Linq; // Min,max,sum
int[] numbers = new int[4];

numbers.Sort();
numbers.Min();
numbers.Sum();

int[,] multiTab = { {1, 4, 2}, {3, 6, 8} };
int[,,] multiTab3D = { { { 1, 2 }, { 3, 4 } }, { { 5, 6 }, { 7, 8 } } };


//Zmienne
int[] tab = {123,123};
long myNum = 15000000000L;
float myFloatNum = 5.75F;
double myDoubleNum = 5.99D;
float f1 = 35e3F;

int myInt = (int)myDoubleNum;
String myString = Convert.ToString(myInt);


// Math
Math.Max(5, 10);
Math.Min(5, 10);
Math.Sqrt(64);
Math.Abs(-4.7);
int a = (int)Math.Round(9.99);

//Console 
#nullable enable
string? read = Console.ReadLine(); // ? - ta zmienna moze być NULL


// string
string t1 = "Ma"; string t2 = "rek"; string test = "test";
string name = $"My name{t1}{t2}";
int d = test.Length;
test.IndexOf("e");
test.ToUpper();
test.ToLower();


int pozycja = test.IndexOf("e");
string lastName = test.Substring(pozycja);


//Short if
//variable = (condition) ? expressionTrue :  expressionFalse;
string result = (16 < 18) ? "Good day." : "Good evening.";
int x = 5;


x ^= 3;   // równoważne: x = x ^ 3; XOR na bitach => 0101 xor 0011 = 0110 => 6

# %% [markdown]
# ### Klasy
# klasy mogą być przechowywane w innych plikach.
#
# ## Dostęp
# Public      - for all
# Private     - only for class
# Protected   - only for class, and inherited
# internal    - same project
