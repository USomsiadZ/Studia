// %%
#include <iostream>
using namespace std;
int main(){
    string name = "Nazwa";
    //cin >> name;
    cout << name;
}
main();
// Out:
// Nazwa

// %%
#include <cstdlib>
#include <vector>

// %%
\t - tab

/*Komentarz*/
//komentarz
% - reszta z dzielenia

// %%
// tablica dynamiczna
vector<int> oceny = {1, 2, 3, 4, 5};
count << oceny[1];
oceny.pop_back();
