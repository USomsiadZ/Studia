// %%
#include <cstdlib> // ogólnego typu
#include <iostream>
#include <vector>
using namespace std;

// %%
// tablica dynamiczna
vector<int> oceny = {1, 2, 3, 4, 5};
count << oceny[1];
oceny.pop_back();
oceny.push_back(10);

\t - tab
% - reszta z dzielenia

// %%
class Student {
    public:
      string name;
      int year;
    
      Student(string n, int y,int c) {
        name = n;
        year = y;
        ocena = c;

      }
      void zwieksz_ocene(){
        ocena++;
      }
    private:
      int ocena = 0;
    };

//Łatwiejsze dodawanie default wartosci
Student ferris("Marek",2004,4);

// %%
//Wskaźniki
int* p = nullptr; // Wskaźnik pusty, nullptr jest specjalną klasą a null to 0 


void swap(&a,&b);

int main() {
  int a = 10;
  int &b = a; // alias
  int *c = &a; // wskaźnik
  cout << a << b << *c;
}

// %%
//Rzutowanie
int y = (int)x;
int z = static_cast<int>x;
