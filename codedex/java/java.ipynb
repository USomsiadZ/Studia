// %%
import java.util.Scanner;
import java.util.Arrays;
import java.util.ArrayList;
import java.util.Collections;
import java.util.Random;

// %%
public class Main {
    public static void main(String[] args) {
    }
}
Main.main(new String[] {});
// Out:
// Hello, Java w Jupyter!

// %%
byte b = 127;
boolean a = true;
// Out:
// -128

// %%
Scanner scanner = new Scanner(System.in);
String name = scanner.nextLine();

scanner.nextDouble()
scanner.nextBoolean()
scanner.nextInt()

// %%
// Arrays
String[] drPepperFlavors = {"Dr Pepper", "Diet Dr Pepper", "Dr Pepper Zero Sugar", "Dr Pepper Strawberries & Cream", "Dr Pepper Cherry"};
int[] ages = {22, 23, 26, 30, 32, 34};
double[] grades = {83.4, 77.9, 62.8, 99.8};

String[] emptyArray = new String[5]; // Creates an empty string array with 5 elements
int[] emptyIntArray = new int[10]; // Creates an empty integer array with 10 elements

System.out.println(ages.length);

Arrays.sort(ages);
System.out.print(Arrays.toString(ages));

int[] a = {1, 2, 3};
int[] b = {1, 2, 3};
int[] c = {3, 2, 1};
System.out.println(Arrays.equals(a, b)); // true

// %%
// Dynamic Arrays
ArrayList<String> name = new ArrayList<>();
ArrayList<Integer> age = new ArrayList<>();
ArrayList<Character> symbol = new ArrayList<>();
name.add("Imie");
name.remove(1);
name.set(1,"Maciej");
name.clear();
name.sort(); // Collection

// %%
//Method overloading - Różna liczba parametrów lub różny typ
public static int add(int a, int b) {...} // add(2, 2) Output: 4
public  static int add(int e, int f, int g) {...} // add(2, 4, 6) Output: 12
public static double add(double a, double b) {...} // add(2.5, 2.5) Output: 5

// %%
class Student{
    String name;
    int mark;
    //Domyśla wartość dla braku parametów - Method overloading
    Student(){
        this(5);
    }
    Student(int mark){
        this.mark = mark;
    }
}
public class klasy{
    
    public static void main(){
        Student student = new Student(1);
        System.out.println(student.mark);



    }
}

// %%
//Regex
String[] slowa = p.trim().split("\\s+");
.trim() // Usuwa białe znaki z końca i początku

// %%
//Random
Random rand = new Random();

// %%
//Math
Math.sqrt()
Math.random()
Math.round()

// %% [markdown]
// | Modyfikator     | Ta sama klasa | Ten sam pakiet | Podklasa (inny pakiet) | Świat (wszystko) |
// |-----------------|---------------|----------------|-------------------------|-------------------|
// | public          | Tak           | Tak            | Tak                     | Tak               |
// | protected       | Tak           | Tak            | Tak                     | Nie               |
// | brak (default)  | Tak           | Tak            | Nie                     | Nie               |
// | private         | Tak           | Nie            | Nie                     | Nie               |

// %%
double randomInflation = min + (max - min) * random.nextDouble();
