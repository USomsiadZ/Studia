# %%
SyntaxError: happens when invalid JavaScript code is present while the program is running.
ReferenceError: happens when you try to use a variable that isn't defined.
TypeError: happens when a data type is being misused during an operation.

# %%
Math.floor(Math.random() * 10);
// Każdy element × 2
numbers.map(n => n * 2);   // [2, 4, 6, 8, 10]

# %%
for (let i = 0; i < 5; i++) {
    if (i == 1) {
      continue;
    }
    console.log(i);
  }

# %%
let lotteryNumbers = [13, 36, 45, 57, 67, 14];
lotteryNumbers.length;
lotteryNumbers.push("Dodanie na koniec");
lotteryNumbers.unshift("Dodanie na początek");
lotteryNumbers.shift(); //Usunięcie z początku
lotteryNumbers.pop(); //Usunięcie z końca
lotteryNumbers.indexOf(13);
lotteryNumbers.includes(value); // True|false

# %%
function dodawanie(){

}

const greetArrow = (name) => "Hello, " + name + "!"; //arrow function
const add = (a, b) => {
    return a + b;
  };

  object = {
    key1: value1,
    key2: value2,
    key3: value3
    func: function () {
      console.log("print")
    }
  }
  object.func();

# %%
<script src="skrypt.js"></script>

# %%
// Select by element name
document.querySelector("p");

// Select by class name
document.querySelector(".class-name");

// Select by id name
document.querySelector("#id-name");

document.querySelector("div").innerHTML;


.getElementById()
.getElementsByClassName("class-example")[0]
document.getElementById("posted").querySelector("p");
.innerText - tekst wewnątrz
document.querySelector("img").src
// Output: 'https://cdn.pixabay.com/photo/2017/05/12/13/17/night-flight-2307018_640.jpg'
document.querySelector("img").src = "smiley2.png"
document.getElementById("posted").style.textAlign = "center";
const randomColor = colors[Math.floor(Math.random() * colors.length)];

likeButton.addEventListener("click", function() {
    p.innerText = "clicked";
    p.style.color = "red";
});

# %% [markdown]
# <img src="img/dom%20style.png" style="width: 40%;" alt="dom style">
