// %%
// Array
using System.Linq; // Min,max,sum
int[] numbers = new[] { 1, 7, 5, 4, 5 };
numbers.Sort();


int[,,] multiTab3D = { { { 1, 2 }, { 3, 4 } }, { { 5, 6 }, { 7, 8 } } };


//Zmienne
long myNum = 15000000000L;
float myFloatNum = 5.75F;
double myDoubleNum = 5.99D;
float f1 = 35e3F;

(int)Math.Round(9.99); // double => int
String myString = Convert.ToString(myInt);

//if A != null => x = A else x = b
#nullable enable
int? A = null;
int B = 5;
int x = A ?? B; // 

// interpolacja stringów
Console.WriteLine($"Imie: {x}");


//variable = (condition) ? expressionTrue :  expressionFalse;
string result = (16 < 18) ? "Good day." : "Good evening.";
int x = 5;

// XOR na bitach => 0101 xor 0011 = 0110 => 6 | równoważne: x = x ^ 3; 
x ^= 3;

// Tablice Dynamiczne
using System.Collections.Generic;

List<string> liczby = [];
liczby = null; // garbage colector usunie tablice

// %% [markdown]
// ### Klasy
// klasy mogą być przechowywane w innych plikach.
//
// ## Dostęp
// Public      - for all
// Private     - only for class
// Protected   - only for class, and inherited
// internal    - same project
//
// ## Modyfikatory
// abstract - cannot be instantiated
// sealed - cannot be inherited
// static - shared across all instances
// virtual - can be overridden
// override - overrides virtual method
