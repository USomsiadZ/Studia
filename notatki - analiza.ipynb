# %%
#Funkcja odwrotna
var('y')
f(x) = (2 - 2*3^x) / (2 + 3^x)
rys = plot( f, (x, -10, 10) )
rozw = solve(y == f(x), x)
rys +=plot( rozw[0].rhs(), (x, -2, 1),color="red")
rys

# %%
#Solve to tablica
f(x) = (x-1)*(x+2)
rozw = solve(f, x)
print(rozw)
for r in rozw:
    if r.rhs() in RR:
        print(r)
# Out:
# [
# x == -2,
# x == 1
# ]
# x == -2
# x == 1

# %%
#Ciągi
a(n) = (2*n-3) / (n+1)
f = [(n, a(n)) for n in range(1, 51)]
rys = points( f, ymin=-0.5, ymax=2.5, size=10, zorder=5 )
rys

# %%
# Wazne
var('y')
roz = solve(y == f(x),x)
