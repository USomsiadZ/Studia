// %%
typedef struct {
    double x;
    double y;
} Point;
int main() {
    Point statek;
}

// %%
FILE *open_file(char *plik){
    FILE *f = fopen(plik, "r");
    if (!f) {
        puts("Błąd odczytu");
    }
    return f;
}
