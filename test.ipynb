# %%
#zad1
#a)
a(n) = ((-1)^(n+1))/(n+1)

sx = sum( a(n), n, 1, 12 ).n()
print('suma częściwa:', sx)
# Out:
# suma częściwa: 0.269866244866245

# %%
#a
S = sum(a(n), n, 1, oo)
print(f"suma {S} \n przyblizenie {S.n()}")
# Out:
# suma -log(2) + 1
#  przyblizenie 0.306852819440055

# %%
#b
var('k')
rys = points( [(n, sum(a(k), k, 1, n)) for n in range(1, 51)], zorder=5 )
rys += plot(S,(x, 0, 10),linestyle='--',color='lightblue',legend_label="granica")
rys
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#(𝑥0 −𝑅,𝑥0 +𝑅) 
#c
var('n')
a1(x) = (x - 2)^n
x0 = 2
R = lim(abs(a(n) / a(n + 1)), n=oo)
r1 = x0 - R
r2 = x0 + R
print(f'przedział: ({r1}, {r2})')


rys += plot(S, (x, r1, r2), color='red', thickness=5)
rys
# Out:
# przedział: (1, 3)
# Graphics object consisting of 3 graphics primitives

# %%
#zad 2
#a)
f(x) = sin(x) - sin(2*x) + sin(3*x)
t = taylor( f(x), x,pi/4,5)

print('Wielomian Taylora:')
print(t)
rys = plot(t,(x,-pi,pi),ymax=5,ymin=-5)
rys += plot(f,(x,-pi,pi),color = "orange")
rys


#c
var('t w')
c = 2*t * exp(-i*w*t)

T = integrate( c, (t,) )
print(T)
# Out:
# Wielomian Taylora:
# 121/122880*sqrt(2)*(pi - 4*x)^5 + 1/6144*(pi - 4*x)^4*(41*sqrt(2) - 16) - 13/384*sqrt(2)*(pi - 4*x)^3 - 1/32*(pi - 4*x)^2*(5*sqrt(2) - 4) + 1/4*sqrt(2)*(pi - 4*x) + sqrt(2) - 1
# 2*I*(t*w - I)*e^(-I*t*w)/w^2

# %%
#b)
f(x) = piecewise([((-5, 0), x + 6), ((0, 0), 0), ((0, 5), x - 4)])
T1 = f.fourier_series_partial_sum(2)
T2 = f.fourier_series_partial_sum(4)
T3 = f.fourier_series_partial_sum(6)
rys = plot([T1,T2,T3],(x,-5,5),color="orange")
rys += plot(f,(x,-5,5))
rys
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
#c
var('t w')
c = 2*t * exp(-i*w*t)

T = integrate( c, (t,-4,4) )
print(T)
# Out:
# 2*(4*I*w - 1)*e^(4*I*w)/w^2 + 2*(4*I*w + 1)*e^(-4*I*w)/w^2

# %%
# zad 3
#a)
f(x,y) = 3 - abs(x) - abs(y)
plot3d( f, (x, -5, 5), (y, -5, 5))
# Out:
# Graphics3d Object

# %%
#b
var("y")
contour_plot( f, (x, -5, 5), 
(y, -5, 5), contours=srange(1/4,11/4,2/4), 
fill=False, labels=True )
# Out:
# Graphics object consisting of 1 graphics primitive
